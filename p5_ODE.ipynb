# %%
# %load_ext autoreload

# %% [markdown]
# # ODE

# %% [markdown]
# ## Ejercicio 1
# $y'= -5y+5t^2+2t$
# * $0 \le t \le 1$
# * $y(t_0)=1/3$
# * $N=10$

# %%
# %autoreload 2
from src import ODE_euler
# Out:
# [02-06 12:52:05][INFO] 2025-02-06 12:52:05.150580
# [02-06 12:52:05][INFO] Dayana| 2025-02-06 12:52:05.334394
# [02-06 12:52:05][INFO] 2025-02-06 12:52:05.336349
# [02-06 12:52:05][INFO] Dayana| 2025-02-06 12:52:05.339277

# %% [markdown]
# ## Comparación con la solución real
# La solución real de la ecuación diferencial es:
# $y(t)=t^2 +1/3e^{-5t}$
#
# * Grafique la solución real y la aproximación obtenida con el método de Euler en una misma gráfica.

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t, y):
    return -5 * y + 5 * t **2 + 2 * t

a = 0
b = 1
N = 10

y0 = 1/3

resultado = ODE_euler(a=a, b=b,f=f, y_t0=y0 ,N=N)
ys = resultado[0]
ts = resultado[1]
h = resultado[2]

print("y=",ys,"t=",ts,"h=",h)
t_real = np.linspace(a, b, 100)
y_real = (t_real) ** 2 + 1/3 * np.exp(-5 * t_real)

plt.figure(figsize=(8, 5))
plt.plot(ts, ys, marker='o', linestyle='--', label='Aproximación Euler', color='skyblue')
plt.plot(t_real, y_real, linestyle='-', label='Solución Real', color='blue')
plt.title('Gráfica de y vs t usando el Método de Euler', fontsize=14)
plt.xlabel('t', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(fontsize=10)
plt.show()
# Out:
# y= [0.3333333333333333, 0.16666666666666666, 0.10833333333333334, 0.11416666666666667, 0.16208333333333336, 0.2410416666666667, 0.34552083333333333, 0.4727604166666667, 0.6213802083333333, 0.7906901041666666, 0.9803450520833332] t= [0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7, 0.7999999999999999, 0.8999999999999999, 0.9999999999999999] h= 0.1

# %% [markdown]
# # Errores
# Calcule el eeror relativo para diferentes valores de N.

# %% [markdown]
# N = 10

# %%
# Calcular error relativo

errores_relativos = [abs((ys - y_real) / y_real) for ys, y_real in zip(ys, y_real)]

for i, error in enumerate(errores_relativos):
    print(f"Punto {i}: Error relativo = {error:.2f}")

promedio_error_relativo = sum(e for i, e in enumerate(errores_relativos)) / len(errores_relativos)
print("Error relativo promedio",promedio_error_relativo)
# Out:
# Punto 0: Error relativo = 0.00
# Punto 1: Error relativo = 0.47
# Punto 2: Error relativo = 0.64
# Punto 3: Error relativo = 0.60
# Punto 4: Error relativo = 0.41
# Punto 5: Error relativo = 0.08
# Punto 6: Error relativo = 0.38
# Punto 7: Error relativo = 0.98
# Punto 8: Error relativo = 1.71
# Punto 9: Error relativo = 2.60
# Punto 10: Error relativo = 3.64
# Error relativo promedio 1.0465862498682021

# %% [markdown]
# N = 5

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t, y):
    return -5 * y + 5 * t **2 + 2 * t

a = 0
b = 1
N = 5

y0 = 1/3

resultado = ODE_euler(a=a, b=b,f=f, y_t0=y0 ,N=N)
ys = resultado[0]
ts = resultado[1]
h = resultado[2]

print("y=",ys,"t=",ts,"h=",h)
t_real = np.linspace(a, b, 100)
y_real = (t_real) ** 2 + 1/3 * np.exp(-5 * t_real)

plt.figure(figsize=(8, 5))
plt.plot(ts, ys, marker='o', linestyle='--', label='Aproximación Euler', color='skyblue')
plt.plot(t_real, y_real, linestyle='-', label='Solución Real', color='blue')
plt.title('Gráfica de y vs t usando el Método de Euler', fontsize=14)
plt.xlabel('t', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(fontsize=10)
plt.show()
# Out:
# y= [0.3333333333333333, 0.0, 0.12000000000000002, 0.32000000000000006, 0.6000000000000001, 0.9600000000000002] t= [0, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0] h= 0.2

# %%
# Calcular error relativo

errores_relativos = [abs((ys - y_real) / y_real) for ys, y_real in zip(ys, y_real)]

for i, error in enumerate(errores_relativos):
    print(f"Punto {i}: Error relativo = {error:.2f}")

promedio_error_relativo = sum(e for i, e in enumerate(errores_relativos)) / len(errores_relativos)
print("Error relativo promedio", promedio_error_relativo)
# Out:
# Punto 0: Error relativo = 0.00
# Punto 1: Error relativo = 1.00
# Punto 2: Error relativo = 0.60
# Punto 3: Error relativo = 0.11
# Punto 4: Error relativo = 1.19
# Punto 5: Error relativo = 2.67
# Error relativo promedio 0.9294638954539126

# %% [markdown]
# N = 20

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t, y):
    return -5 * y + 5 * t **2 + 2 * t

a = 0
b = 1
N = 20

y0 = 1/3

resultado = ODE_euler(a=a, b=b,f=f, y_t0=y0 ,N=N)
ys = resultado[0]
ts = resultado[1]
h = resultado[2]

print("y=",ys,"t=",ts,"h=",h)
t_real = np.linspace(a, b, 100)
y_real = (t_real) ** 2 + 1/3 * np.exp(-5 * t_real)

plt.figure(figsize=(8, 5))
plt.plot(ts, ys, marker='o', linestyle='--', label='Aproximación Euler', color='skyblue')
plt.plot(t_real, y_real, linestyle='-', label='Solución Real', color='blue')
plt.title('Gráfica de y vs t usando el Método de Euler', fontsize=14)
plt.xlabel('t', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(fontsize=10)
plt.show()
# Out:
# y= [0.3333333333333333, 0.25, 0.193125, 0.15734375, 0.1386328125, 0.133974609375, 0.14110595703125, 0.1583294677734375, 0.18437210083007813, 0.21827907562255858, 0.2593343067169189, 0.3070007300376892, 0.3608755475282669, 0.42065666064620016, 0.4861174954846501, 0.5570881216134876, 0.6334410912101158, 0.715080818407587, 0.8019356138056903, 0.8939517103542679, 0.9910887827657011] t= [0, 0.05, 0.1, 0.15000000000000002, 0.2, 0.25, 0.3, 0.35, 0.39999999999999997, 0.44999999999999996, 0.49999999999999994, 0.5499999999999999, 0.6, 0.65, 0.7000000000000001, 0.7500000000000001, 0.8000000000000002, 0.8500000000000002, 0.9000000000000002, 0.9500000000000003, 1.0000000000000002] h= 0.05

# %%
# Calcular error relativo

errores_relativos = [abs((ys - y_real) / y_real) for ys, y_real in zip(ys, y_real)]

for i, error in enumerate(errores_relativos):
    print(f"Punto {i}: Error relativo = {error:.2f}")

promedio_error_relativo = sum(e for i, e in enumerate(errores_relativos)) / len(errores_relativos)
print("Error relativo promedio", promedio_error_relativo)
# Out:
# Punto 0: Error relativo = 0.00
# Punto 1: Error relativo = 0.23
# Punto 2: Error relativo = 0.38
# Punto 3: Error relativo = 0.47
# Punto 4: Error relativo = 0.51
# Punto 5: Error relativo = 0.49
# Punto 6: Error relativo = 0.42
# Punto 7: Error relativo = 0.31
# Punto 8: Error relativo = 0.14
# Punto 9: Error relativo = 0.07
# Punto 10: Error relativo = 0.34
# Punto 11: Error relativo = 0.65
# Punto 12: Error relativo = 1.02
# Punto 13: Error relativo = 1.44
# Punto 14: Error relativo = 1.91
# Punto 15: Error relativo = 2.44
# Punto 16: Error relativo = 3.01
# Punto 17: Error relativo = 3.64
# Punto 18: Error relativo = 4.31
# Punto 19: Error relativo = 5.02
# Error relativo promedio 1.3401519065735759
